# %%
# !mkdir ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# # Bias in Helmet Detection

# %%
# !kaggle datasets download -d andrewmvd/helmet-detection
# !unzip helmet-detection.zip -d helmet_data

# %%
import os
import xml.etree.ElementTree as ET
from collections import Counter

# Paths
annotations_path = 'helmet_data/annotations'

# Initialize counter
label_counter = Counter()

# Loop through all XML annotation files
for label_file in os.listdir(annotations_path):
    if label_file.endswith('.xml'):
        xml_path = os.path.join(annotations_path, label_file)
        tree = ET.parse(xml_path)
        root = tree.getroot()

        for obj in root.findall('object'):
            class_name = obj.find('name').text
            label_counter[class_name] += 1

# Display total class distribution
print("✅ Class Counts (Total Across Dataset):")
total = sum(label_counter.values())
for cls, count in label_counter.items():
    percentage = (count / total) * 100
    print(f"Class '{cls}': {count} samples ({percentage:.2f}%)")
# Out:
# ✅ Class Counts (Total Across Dataset):
# Class 'Without Helmet': 489 samples (33.70%)
# Class 'With Helmet': 962 samples (66.30%)

# %% [markdown]
# This imbalance can lead to:
#
# The model learning to predict "With Helmet" more often (since it’s safer statistically)
#
# Lower recall on the 'Without Helmet' class
#
# What we did in our process was class aware augmentation.

# %% [markdown]
# ##Checking average brightness

# %%
import cv2
import os

def classify_day_night(image_path, threshold=100):
    """Classify image as 'day' or 'night' based on average brightness."""
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    brightness = gray.mean()
    return "day" if brightness > threshold else "night"

# Example usage on a folder
folder_path = "helmet_data/images"
day_count = 0
night_count = 0
total = 0

for filename in os.listdir(folder_path):
    if filename.lower().endswith((".jpg", ".jpeg", ".png")):
        path = os.path.join(folder_path, filename)
        label = classify_day_night(path)
        if label == "day":
            day_count += 1
        else:
            night_count += 1
        total += 1

# Print summary
if total > 0:
    day_pct = (day_count / total) * 100
    night_pct = (night_count / total) * 100
    print(f"\nTotal images: {total}")
    print(f"Day: {day_count} images ({day_pct:.2f}%)")
    print(f"Night: {night_count} images ({night_pct:.2f}%)")
else:
    print("No valid images found in the folder.")
# Out:
# Total images: 764
# Day: 642 images (84.03%)
# Night: 122 images (15.97%)

# %% [markdown]
# Checking crowdedness

# %%
pip install ultralytics

# %%
from ultralytics import YOLO
import os

# Load pretrained YOLOv8 model (COCO)
model = YOLO("yolov8n.pt")  # or yolov8s.pt, etc.

# Vehicle-related COCO class IDs
vehicle_classes = ['car', 'truck', 'bus', 'motorbike', 'bicycle']

def classify_crowdedness(image_path, threshold=5):
    results = model(image_path)
    boxes = results[0].boxes
    names = results[0].names

    # Count number of detected vehicles
    count = 0
    for cls_id in boxes.cls.cpu().numpy().astype(int):
        label = names[cls_id]
        if label in vehicle_classes:
            count += 1

    crowdedness = "crowded" if count > threshold else "not_crowded"
    return count, crowdedness

# Example usage
folder_path = "helmet_data/images"
for filename in os.listdir(folder_path):
    if filename.lower().endswith((".jpg", ".jpeg", ".png")):
        path = os.path.join(folder_path, filename)
        count, label = classify_crowdedness(path)
        print(f"{filename}: {label} ({count} vehicles)")
# Out:
# image 1/1 /content/helmet_data/images/BikesHelmets588.png: 416x640 4 persons, 1 car, 1 motorcycle, 340.1ms
# Speed: 18.8ms preprocess, 340.1ms inference, 37.7ms postprocess per image at shape (1, 3, 416, 640)
# BikesHelmets588.png: not_crowded (1 vehicles)
#
# image 1/1 /content/helmet_data/images/BikesHelm
5ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# BikesHelmets106.png: not_crowded (2 vehicles)
#
# image 1/1 /content/helmet_data/images/BikesHelmets481.png: 512x640 2 persons, 3 cars, 1 motorcycle, 271.3ms
# Speed: 4.6ms preprocess, 271.3ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 640)
# BikesHelmets481.png: not_crowded (3 vehicles)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-e977de869c16> in <cell line: 0>()
#      28     if filename.lower().endswith((".jpg", ".jpeg", ".png")):
#      29         path = os.path.join(folder_path, filename)
# ---> 30         count, label = classify_crowdedness(path)
#      31         print(f"{filename}: {label} ({count} vehicles)")
#
# <ipython-input-17-e977de869c16> in classify_crowdedness(image_path, threshold)
#       9
#      10 def classify_crowdedness(image_path, threshold=5):
# ---> 11     results = model(image_path)
#      12     boxes = results[0].boxes
#      13     names = results[0].names
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in __call__(self, source, stream, **kwargs)
#     179             ...     print(f"Detected {len(r)} objects in image")
#     180         """
# --> 181         return self.predict(source, stream, **kwargs)
#     182
#     183     @staticmethod
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     547         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     548             self.predictor.set_prompts(prompts)
# --> 549         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     550
#     551     def track(
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     216             return self.stream_inference(source, model, *args, **kwargs)
#     217         else:
# --> 218             return list(self.stream_inference(source, model, *args, **kwargs))  # merge list of Result into one
#     219
#     220     def predict_cli(self, source=None, model=None):
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in generator_context(*args, **kwargs)
#      34             # Issuing `None` to a generator fires it up
#      35             with ctx_factory():
# ---> 36                 response = gen.send(None)
#      37
#      38             while True:
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/predictor.py in stream_inference(self, source, model, *args, **kwargs)
#     327                 # Inference
#     328                 with profilers[1]:
# --> 329                     preds = self.inference(im, *args, **kwargs)
#     330                     if self.args.embed:
#     331                         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/predictor.py in inference(self, im, *args, **kwargs)
#     171             else False
#     172         )
# --> 173         return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#     174
#     175     def pre_transform(self, im):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/autobackend.py in forward(self, im, augment, visualize, embed, **kwargs)
#     590         # PyTorch
#     591         if self.pt or self.nn_module:
# --> 592             y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     593
#     594         # TorchScript
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py in forward(self, x, *args, **kwargs)
#     118         if isinstance(x, dict):  # for cases of training and validating while training.
#     119             return self.loss(x, *args, **kwargs)
# --> 120         return self.predict(x, *args, **kwargs)
#     121
#     122     def predict(self, x, profile=False, visualize=False, augment=False, embed=None):
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py in predict(self, x, profile, visualize, augment, embed)
#     136         if augment:
#     137             return self._predict_augment(x)
# --> 138         return self._predict_once(x, profile, visualize, embed)
#     139
#     140     def _predict_once(self, x, profile=False, visualize=False, embed=None):
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py in _predict_once(self, x, profile, visualize, embed)
#     157             if profile:
#     158                 self._profile_one_layer(m, x, dt)
# --> 159             x = m(x)  # run
#     160             y.append(x if m.i in self.save else None)  # save output
#     161             if visualize:
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py in forward(self, x)
#     299         """Forward pass through C2f layer."""
#     300         y = list(self.cv1(x).chunk(2, 1))
# --> 301         y.extend(m(y[-1]) for m in self.m)
#     302         return self.cv2(torch.cat(y, 1))
#     303
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py in <genexpr>(.0)
#     299         """Forward pass through C2f layer."""
#     300         y = list(self.cv1(x).chunk(2, 1))
# --> 301         y.extend(m(y[-1]) for m in self.m)
#     302         return self.cv2(torch.cat(y, 1))
#     303
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py in forward(self, x)
#     474     def forward(self, x):
#     475         """Apply bottleneck with optional shortcut connection."""
# --> 476         return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#     477
#     478
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/conv.py in forward_fuse(self, x)
#      89             (torch.Tensor): Output tensor.
#      90         """
# ---> 91         return self.act(self.conv(x))
#      92
#      93
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     552
#     553     def forward(self, input: Tensor) -> Tensor:
# --> 554         return self._conv_forward(input, self.weight, self.bias)
#     555
#     556
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     547                 self.groups,
#     548             )
# --> 549         return F.conv2d(
#     550             input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551         )
#
# KeyboardInterrupt:

# %%
from ultralytics import YOLO
import os

# Load pretrained YOLOv8 model (COCO)
model = YOLO("yolov8n.pt")  # or yolov8s.pt, etc.

# Vehicle-related COCO class labels
vehicle_classes = ['car', 'truck', 'bus', 'motorbike', 'bicycle']

def count_vehicles(image_path):
    results = model(image_path)
    boxes = results[0].boxes
    names = results[0].names

    count = 0
    for cls_id in boxes.cls.cpu().numpy().astype(int):
        label = names[cls_id]
        if label in vehicle_classes:
            count += 1
    return count

# Folder path
folder_path = "helmet_data/images"
total_count = 0
image_count = 0

# Process each image
for filename in os.listdir(folder_path):
    if filename.lower().endswith((".jpg", ".jpeg", ".png")):
        path = os.path.join(folder_path, filename)
        vehicle_count = count_vehicles(path)
        total_count += vehicle_count
        image_count += 1

# Summary
if image_count > 0:
    average = total_count / image_count
    print(f"\nProcessed {image_count} images")
    print(f"Total vehicles detected: {total_count}")
    print(f"Average vehicles per image: {average:.2f}")
else:
    print("No valid images found in the folder.")
# Out:
# image 1/1 /content/helmet_data/images/BikesHelmets588.png: 416x640 4 persons, 1 car, 1 motorcycle, 140.3ms
# Speed: 3.5ms preprocess, 140.3ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets71.png: 384x640 2 persons, 2 motorcycles, 146.6ms
# Speed: 2.7ms preprocess, 146.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets527.png: 352x640 5 persons, 2 motorcycles, 138.7ms
# Speed: 2.2ms preprocess, 138.7ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets145.png: 320x640 6 persons, 4 bicycles, 147.5ms
# Speed: 3.0ms preprocess, 147.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets733.png: 448x640 1 person, 6 motorcycles, 150.8ms
# Speed: 2.6ms preprocess, 150.8ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets347.png: 448x640 2 persons, 2 motorcycles, 145.8ms
# Speed: 3.0ms preprocess, 145.8ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets236.png: 416x640 5 persons, 1 bicycle, 140.8ms
# Speed: 2.6ms preprocess, 140.8ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets371.png: 416x640 6 persons, 4 motorcycles, 144.7ms
# Speed: 2.5ms preprocess, 144.7ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets648.png: 448x640 2 persons, 149.6ms
# Speed: 2.9ms preprocess, 149.6ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets521.png: 384x640 1 person, 1 motorcycle, 127.7ms
# Speed: 2.2ms preprocess, 127.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets212.png: 448x640 1 person, 1 motorcycle, 145.7ms
# Speed: 2.6ms preprocess, 145.7ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets492.png: 608x640 2 persons, 208.4ms
# Speed: 3.8ms preprocess, 208.4ms inference, 1.6ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets162.png: 640x448 1 person, 2 bicycles, 150.9ms
# Speed: 2.8ms preprocess, 150.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/helmet_data/images/BikesHelmets554.png: 384x640 9 persons, 3 motorcycles, 142.4ms
# Speed: 2.3ms preprocess, 142.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets570.png: 480x640 1 person, 1 motorcycle, 3 trucks, 155.9ms
# Speed: 2.8ms preprocess, 155.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets665.png: 480x640 9 persons, 7 motorcycles, 152.8ms
# Speed: 2.8ms preprocess, 152.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets549.png: 448x640 1 person, 1 car, 1 motorcycle, 147.6ms
# Speed: 2.7ms preprocess, 147.6ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets170.png: 448x640 1 person, 1 motorcycle, 143.4ms
# Speed: 2.6ms preprocess, 143.4ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets725.png: 416x640 7 persons, 5 motorcycles, 136.5ms
# Speed: 2.5ms preprocess, 136.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets330.png: 544x640 1 person, 1 car, 1 handbag, 2 potted plants, 262.5ms
# Speed: 3.5ms preprocess, 262.5ms inference, 2.9ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets534.png: 576x640 1 person, 1 bicycle, 196.3ms
# Speed: 3.3ms preprocess, 196.3ms inference, 1.4ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets102.png: 640x640 3 persons, 4 bicycles, 1 car, 210.0ms
# Speed: 3.7ms preprocess, 210.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets573.png: 448x640 3 persons, 3 bicycles, 1 car, 2 trucks, 144.6ms
# Speed: 3.3ms preprocess, 144.6ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets295.png: 640x448 3 persons, 1 motorcycle, 147.1ms
# Speed: 2.7ms preprocess, 147.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/helmet_data/images/BikesHelmets279.png: 640x640 1 person, 229.0ms
# Speed: 3.8ms preprocess, 229.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets20.png: 640x480 3 persons, 3 cars, 3 motorcycles, 159.6ms
# Speed: 2.9ms preprocess, 159.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/helmet_data/images/BikesHelm
ms preprocess, 149.7ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets215.png: 448x640 16 persons, 6 motorcycles, 153.2ms
# Speed: 3.1ms preprocess, 153.2ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets154.png: 640x512 8 persons, 2 cars, 2 motorcycles, 1 bus, 1 truck, 1 handbag, 200.6ms
# Speed: 4.5ms preprocess, 200.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /content/helmet_data/images/BikesHelmets591.png: 640x480 1 person, 1 bicycle, 156.0ms
# Speed: 2.8ms preprocess, 156.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/helmet_data/images/BikesHelmets74.png: 448x640 2 persons, 3 motorcycles, 142.9ms
# Speed: 2.6ms preprocess, 142.9ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets344.png: 384x640 18 persons, 11 bicycles, 131.9ms
# Speed: 2.5ms preprocess, 131.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets546.png: 448x640 1 person, 1 bicycle, 144.1ms
# Speed: 2.6ms preprocess, 144.1ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets596.png: 384x640 8 persons, 6 bicycles, 131.9ms
# Speed: 2.9ms preprocess, 131.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets6.png: 384x640 14 persons, 5 motorcycles, 146.1ms
# Speed: 2.4ms preprocess, 146.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets418.png: 448x640 1 person, 1 motorcycle, 144.6ms
# Speed: 2.6ms preprocess, 144.6ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets586.png: 448x640 15 persons, 6 motorcycles, 147.5ms
# Speed: 2.7ms preprocess, 147.5ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets691.png: 448x640 1 person, 151.0ms
# Speed: 2.8ms preprocess, 151.0ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets87.png: 448x640 11 persons, 4 bicycles, 3 backpacks, 1 umbrella, 148.8ms
# Speed: 2.7ms preprocess, 148.8ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets714.png: 640x480 2 persons, 1 bicycle, 160.6ms
# Speed: 3.2ms preprocess, 160.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/helmet_data/images/BikesHelmets451.png: 448x640 1 person, 1 motorcycle, 160.4ms
# Speed: 2.9ms preprocess, 160.4ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets667.png: 384x640 2 persons, 2 cars, 1 motorcycle, 1 sports ball, 133.1ms
# Speed: 2.4ms preprocess, 133.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets332.png: 448x640 7 persons, 5 bicycles, 145.5ms
# Speed: 2.7ms preprocess, 145.5ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets370.png: 480x640 2 persons, 1 car, 1 motorcycle, 157.1ms
# Speed: 2.7ms preprocess, 157.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets369.png: 448x640 6 persons, 2 cars, 2 motorcycles, 3 buss, 1 truck, 148.7ms
# Speed: 2.6ms preprocess, 148.7ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets11.png: 480x640 12 persons, 4 motorcycles, 154.9ms
# Speed: 2.9ms preprocess, 154.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets284.png: 384x640 3 persons, 1 motorcycle, 145.4ms
# Speed: 2.5ms preprocess, 145.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets576.png: 640x448 1 person, 1 bicycle, 2 cars, 145.3ms
# Speed: 2.5ms preprocess, 145.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/helmet_data/images/BikesHelmets335.png: 640x480 4 persons, 4 motorcycles, 160.4ms
# Speed: 2.9ms preprocess, 160.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/helmet_data/images/BikesHelmets496.png: 480x640 3 persons, 1 motorcycle, 1 potted plant, 152.7ms
# Speed: 3.1ms preprocess, 152.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets242.png: 448x640 6 persons, 3 cars, 7 motorcycles, 147.9ms
# Speed: 2.5ms preprocess, 147.9ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets509.png: 640x448 2 persons, 5 bicycles, 245.1ms
# Speed: 3.3ms preprocess, 245.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/helmet_data/images/BikesHelmets523.png: 480x640 4 persons, 2 bicycles, 1 car, 1 backpack, 1 handbag, 240.3ms
# Speed: 4.0ms preprocess, 240.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets619.png: 480x640 8 persons, 1 motorcycle, 1 dining table, 236.8ms
# Speed: 4.8ms preprocess, 236.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets718.png: 352x640 2 persons, 3 bicycles, 6 cars, 1 backpack, 181.9ms
# Speed: 3.3ms preprocess, 181.9ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelm
5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets3.png: 352x640 7 persons, 2 bicycles, 1 car, 2 motorcycles, 121.1ms
# Speed: 2.2ms preprocess, 121.1ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets717.png: 544x640 6 persons, 3 cars, 1 motorcycle, 1 truck, 172.9ms
# Speed: 3.5ms preprocess, 172.9ms inference, 1.5ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets505.png: 448x640 4 persons, 1 bicycle, 2 cars, 145.1ms
# Speed: 2.7ms preprocess, 145.1ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets92.png: 448x640 1 person, 3 cars, 1 motorcycle, 143.9ms
# Speed: 2.6ms preprocess, 143.9ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets495.png: 384x640 2 persons, 2 bicycles, 140.7ms
# Speed: 2.4ms preprocess, 140.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets384.png: 640x512 1 person, 1 bicycle, 170.2ms
# Speed: 3.0ms preprocess, 170.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /content/helmet_data/images/BikesHelmets752.png: 384x640 5 persons, 5 bicycles, 2 handbags, 132.5ms
# Speed: 2.4ms preprocess, 132.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets553.png: 448x640 5 persons, 2 bicycles, 3 cars, 145.9ms
# Speed: 2.6ms preprocess, 145.9ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets524.png: 384x640 2 persons, 1 motorcycle, 130.9ms
# Speed: 2.2ms preprocess, 130.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets256.png: 384x640 7 persons, 1 bicycle, 3 motorcycles, 124.3ms
# Speed: 3.2ms preprocess, 124.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets456.png: 640x448 3 persons, 1 backpack, 152.5ms
# Speed: 2.6ms preprocess, 152.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/helmet_data/images/BikesHelmets151.png: 384x640 1 person, 1 motorcycle, 1 bench, 130.4ms
# Speed: 2.7ms preprocess, 130.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets745.png: 320x640 1 person, 1 motorcycle, 108.0ms
# Speed: 1.9ms preprocess, 108.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets670.png: 480x640 5 persons, 1 bicycle, 1 car, 1 motorcycle, 153.1ms
# Speed: 2.8ms preprocess, 153.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets149.png: 480x640 3 persons, 2 bicycles, 1 backpack, 151.7ms
# Speed: 2.8ms preprocess, 151.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets285.png: 640x448 1 person, 145.1ms
# Speed: 2.9ms preprocess, 145.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/helmet_data/images/BikesHelmets719.png: 608x640 3 persons, 3 cars, 2 motorcycles, 1 truck, 199.0ms
# Speed: 3.5ms preprocess, 199.0ms inference, 2.2ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets609.png: 448x640 17 persons, 16 bicycles, 1 car, 1 motorcycle, 141.5ms
# Speed: 5.5ms preprocess, 141.5ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets200.png: 480x640 5 persons, 2 cars, 1 motorcycle, 1 truck, 1 backpack, 150.7ms
# Speed: 2.9ms preprocess, 150.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets152.png: 448x640 9 persons, 8 motorcycles, 144.3ms
# Speed: 2.6ms preprocess, 144.3ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets641.png: 480x640 3 persons, 1 bicycle, 1 potted plant, 155.8ms
# Speed: 2.9ms preprocess, 155.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets612.png: 480x640 1 person, 2 motorcycles, 154.0ms
# Speed: 3.0ms preprocess, 154.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets559.png: 416x640 5 persons, 1 motorcycle, 1 backpack, 137.5ms
# Speed: 2.5ms preprocess, 137.5ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets133.png: 448x640 14 persons, 1 car, 1 motorcycle, 156.0ms
# Speed: 3.9ms preprocess, 156.0ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets722.png: 640x448 1 person, 1 bicycle, 151.3ms
# Speed: 3.6ms preprocess, 151.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/helmet_data/images/BikesHelmets543.png: 640x480 1 person, 2 bicycles, 1 car, 1 tennis racket, 158.6ms
# Speed: 2.9ms preprocess, 158.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/helmet_data/images/BikesHelmets304.png: 448x640 9 persons, 5 motorcycles, 1 umbrella, 193.8ms
# Speed: 2.8ms preprocess, 193.8ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets302.png: 416x640 2 persons, 1 motorcycle, 175.5ms
# Speed: 4.7ms preprocess, 175.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets388.png: 512x640 1 person, 2 chairs, 1 remote, 182.2ms
# Speed: 4.0ms preprocess, 182.2ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets221.png: 288x640 9 persons, 3 bicycles, 2 cars, 106.5ms
# Speed: 1.8ms preprocess, 106.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets95.png: 640x640 2 persons, 2 bicycles, 200.3ms
# Speed: 4.0ms preprocess, 200.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets206.png: 640x448 1 person, 1 baseball bat, 145.3ms
# Speed: 2.7ms preprocess, 145.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/helmet_data/images/BikesHelmets143.png: 384x640 11 persons, 1 car, 6 motorcycles, 1 bus, 129.2ms
# Speed: 2.3ms preprocess, 129.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets245.png: 640x640 5 persons, 1 car, 2 motorcycles, 1 traffic light, 211.6ms
# Speed: 3.7ms preprocess, 211.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# ...
# Speed: 3.3ms preprocess, 171.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets693.png: 448x640 2 persons, 147.9ms
# Speed: 2.7ms preprocess, 147.9ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets676.png: 480x640 8 persons, 5 bicycles, 1 motorcycle, 1 traffic light, 153.8ms
# Speed: 4.2ms preprocess, 153.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets470.png: 640x480 3 persons, 3 cars, 3 motorcycles, 157.0ms
# Speed: 2.9ms preprocess, 157.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/helmet_data/images/BikesHelmets320.png: 448x640 5 persons, 5 bicycles, 1 motorcycle, 150.0ms
# Speed: 4.0ms preprocess, 150.0ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets207.png: 544x640 3 persons, 3 bicycles, 179.4ms
# Speed: 3.4ms preprocess, 179.4ms inference, 1.7ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets643.png: 448x640 15 persons, 2 motorcycles, 191.9ms
# Speed: 2.8ms preprocess, 191.9ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets592.png: 512x640 17 persons, 3 bicycles, 1 dog, 177.8ms
# Speed: 4.2ms preprocess, 177.8ms inference, 3.3ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets7.png: 448x640 10 persons, 6 motorcycles, 226.0ms
# Speed: 3.9ms preprocess, 226.0ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets399.png: 448x640 11 persons, 7 bicycles, 4 cars, 2 traffic lights, 226.2ms
# Speed: 4.0ms preprocess, 226.2ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets602.png: 384x640 1 person, 1 bicycle, 208.0ms
# Speed: 3.1ms preprocess, 208.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets482.png: 384x640 1 person, 6 cars, 216.4ms
# Speed: 3.2ms preprocess, 216.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets748.png: 448x640 1 person, 1 motorcycle, 230.1ms
# Speed: 3.7ms preprocess, 230.1ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets611.png: 416x640 3 persons, 3 bicycles, 207.4ms
# Speed: 3.5ms preprocess, 207.4ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets53.png: 448x640 1 person, 1 motorcycle, 234.7ms
# Speed: 3.7ms preprocess, 234.7ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets103.png: 448x640 5 persons, 1 motorcycle, 223.6ms
# Speed: 3.8ms preprocess, 223.6ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets449.png: 448x640 11 persons, 7 bicycles, 232.1ms
# Speed: 3.9ms preprocess, 232.1ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets582.png: 448x640 3 persons, 4 bicycles, 224.8ms
# Speed: 4.7ms preprocess, 224.8ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets423.png: 640x480 3 persons, 1 motorcycle, 246.5ms
# Speed: 4.5ms preprocess, 246.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/helmet_data/images/BikesHelmets723.png: 448x640 1 person, 3 cars, 1 motorcycle, 215.8ms
# Speed: 5.2ms preprocess, 215.8ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets404.png: 384x640 2 persons, 1 motorcycle, 125.0ms
# Speed: 2.3ms preprocess, 125.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets38.png: 448x640 3 persons, 2 bicycles, 1 car, 1 backpack, 144.7ms
# Speed: 2.7ms preprocess, 144.7ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets707.png: 480x640 3 persons, 1 motorcycle, 155.0ms
# Speed: 4.2ms preprocess, 155.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets720.png: 480x640 4 persons, 2 bicycles, 4 cars, 1 bus, 2 trucks, 155.6ms
# Speed: 3.8ms preprocess, 155.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets129.png: 448x640 1 person, 1 bicycle, 147.0ms
# Speed: 3.2ms preprocess, 147.0ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets753.png: 448x640 2 persons, 1 motorcycle, 150.8ms
# Speed: 3.7ms preprocess, 150.8ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets57.png: 384x640 7 persons, 1 car, 1 motorcycle, 1 bus, 126.9ms
# Speed: 2.5ms preprocess, 126.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets615.png: 448x640 1 person, 1 bicycle, 3 cars, 1 bus, 3 traffic lights, 144.7ms
# Speed: 2.6ms preprocess, 144.7ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets460.png: 224x640 7 persons, 7 cars, 1 handbag, 78.5ms
# Speed: 2.2ms preprocess, 78.5ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets203.png: 448x640 8 persons, 9 motorcycles, 142.4ms
# Speed: 3.1ms preprocess, 142.4ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets436.png: 640x448 2 persons, 1 skateboard, 145.4ms
# Speed: 3.5ms preprocess, 145.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/helmet_data/images/BikesHelmets229.png: 448x640 1 person, 1 motorcycle, 157.2ms
# Speed: 2.7ms preprocess, 157.2ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets197.png: 512x640 2 persons, 1 motorcycle, 1 umbrella, 1 potted plant, 165.9ms
# Speed: 3.9ms preprocess, 165.9ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets216.png: 352x640 1 person, 1 bicycle, 1 car, 1 motorcycle, 1 truck, 1 chair, 118.4ms
# Speed: 2.4ms preprocess, 118.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets605.png: 480x640 7 persons, 1 motorcycle, 2 backpacks, 154.1ms
# Speed: 4.2ms preprocess, 154.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets243.png: 544x640 1 person, 175.1ms
# Speed: 3.5ms preprocess, 175.1ms inference, 1.8ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets400.png: 640x640 1 person, 1 bicycle, 214.6ms
# Speed: 3.9ms preprocess, 214.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets341.png: 640x384 1 person, 1 bicycle, 134.9ms
# Speed: 3.2ms preprocess, 134.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /content/helmet_data/images/BikesHelmets403.png: 384x640 17 persons, 5 bicycles, 2 cars, 1 motorcycle, 1 truck, 126.4ms
# Speed: 2.3ms preprocess, 126.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets477.png: 416x640 1 person, 1 motorcycle, 135.4ms
# Speed: 2.6ms preprocess, 135.4ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets346.png: 640x640 1 person, 1 bicycle, 198.1ms
# Speed: 4.9ms preprocess, 198.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets488.png: 512x640 2 persons, 1 bicycle, 169.7ms
# Speed: 3.9ms preprocess, 169.7ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets706.png: 480x640 5 persons, 1 motorcycle, 164.3ms
# Speed: 2.9ms preprocess, 164.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets349.png: 608x640 5 persons, 1 car, 1 motorcycle, 186.8ms
# Speed: 3.6ms preprocess, 186.8ms inference, 1.5ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets427.png: 384x640 1 person, 2 cars, 1 motorcycle, 132.2ms
# Speed: 3.4ms preprocess, 132.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets377.png: 448x640 10 persons, 7 bicycles, 142.4ms
# Speed: 2.7ms preprocess, 142.4ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets544.png: 544x640 1 person, 1 bicycle, 1 car, 175.6ms
# Speed: 3.2ms preprocess, 175.6ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets296.png: 480x640 3 persons, 1 motorcycle, 1 potted plant, 150.6ms
# Speed: 3.2ms preprocess, 150.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets589.png: 416x640 2 persons, 2 bicycles, 152.0ms
# Speed: 2.5ms preprocess, 152.0ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets758.png: 480x640 2 persons, 2 bicycles, 1 backpack, 1 bottle, 155.4ms
# Speed: 2.8ms preprocess, 155.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets192.png: 352x640 1 person, 1 car, 1 motorcycle, 117.4ms
# Speed: 3.0ms preprocess, 117.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets356.png: 448x640 4 persons, 5 bicycles, 143.8ms
# Speed: 3.0ms preprocess, 143.8ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets286.png: 256x640 3 persons, 1 bicycle, 2 cars, 1 truck, 1 backpack, 92.4ms
# Speed: 1.6ms preprocess, 92.4ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets325.png: 416x640 15 persons, 11 bicycles, 1 car, 2 traffic lights, 2 backpacks, 134.7ms
# Speed: 2.6ms preprocess, 134.7ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets340.png: 608x640 2 persons, 1 motorcycle, 1 dog, 203.4ms
# Speed: 3.9ms preprocess, 203.4ms inference, 1.6ms postprocess per image at shape (1, 3, 608, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets638.png: 640x512 7 persons, 1 motorcycle, 169.5ms
# Speed: 3.1ms preprocess, 169.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /content/helmet_data/images/BikesHelmets721.png: 480x640 2 persons, 1 motorcycle, 162.3ms
# Speed: 3.8ms preprocess, 162.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets373.png: 448x640 2 persons, 1 bicycle, 143.6ms
# Speed: 3.6ms preprocess, 143.6ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets66.png: 480x640 2 persons, 1 motorcycle, 151.9ms
# Speed: 3.0ms preprocess, 151.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets627.png: 384x640 2 persons, 1 motorcycle, 2 backpacks, 129.6ms
# Speed: 3.6ms preprocess, 129.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets227.png: 640x448 4 persons, 1 bicycle, 154.7ms
# Speed: 3.8ms preprocess, 154.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/helmet_data/images/BikesHelmets631.png: 480x640 13 persons, 1 bicycle, 1 motorcycle, 155.8ms
# Speed: 4.2ms preprocess, 155.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets277.png: 384x640 14 persons, 5 motorcycles, 137.9ms
# Speed: 2.3ms preprocess, 137.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets363.png: 448x640 1 person, 1 bicycle, 151.8ms
# Speed: 3.5ms preprocess, 151.8ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets430.png: 512x640 2 persons, 2 bicycles, 3 cars, 1 bus, 5 traffic lights, 194.6ms
# Speed: 4.4ms preprocess, 194.6ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets637.png: 448x640 4 persons, 3 motorcycles, 1 backpack, 159.4ms
# Speed: 2.7ms preprocess, 159.4ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets433.png: 384x640 4 persons, 2 bicycles, 1 stop sign, 132.2ms
# Speed: 3.6ms preprocess, 132.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets715.png: 448x640 1 person, 150.2ms
# Speed: 3.8ms preprocess, 150.2ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets51.png: 480x640 1 person, 1 motorcycle, 149.8ms
# Speed: 3.3ms preprocess, 149.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets88.png: 448x640 2 persons, 1 motorcycle, 141.8ms
# Speed: 3.9ms preprocess, 141.8ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets30.png: 640x448 4 persons, 2 bicycles, 2 cars, 144.4ms
# Speed: 2.7ms preprocess, 144.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/helmet_data/images/BikesHelmets571.png: 640x640 7 persons, 6 cars, 3 motorcycles, 2 trucks, 215.6ms
# Speed: 3.8ms preprocess, 215.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets65.png: 384x640 3 persons, 2 bicycles, 125.7ms
# Speed: 2.3ms preprocess, 125.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets608.png: 384x640 5 persons, 1 car, 128.4ms
# Speed: 2.3ms preprocess, 128.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets653.png: 416x640 1 person, 135.5ms
# Speed: 2.8ms preprocess, 135.5ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets398.png: 384x640 7 persons, 4 motorcycles, 2 backpacks, 152.6ms
# Speed: 2.4ms preprocess, 152.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets331.png: 448x640 4 persons, 2 cars, 1 motorcycle, 1 truck, 232.8ms
# Speed: 3.6ms preprocess, 232.8ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/helmet_data/images/BikesHelmets383.png: 640x640 7 persons, 1 motorcycle, 323.5ms
# Speed: 6.7ms preprocess, 323.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# Processed 764 images
# Total vehicles detected: 1557
# Average vehicles per image: 2.04
